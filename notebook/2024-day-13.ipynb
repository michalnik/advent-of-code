# %%
import typing
from dataclasses import dataclass, field
from math import gcd


FilePath: typing.TypeAlias = str
FileContent: typing.TypeAlias = typing.Iterator[str]


class FileReader(typing.Protocol):
    def __call__(self, file: FilePath) -> FileContent: ...


def file_reader(file: FilePath) -> FileContent:
    with open(file) as file_handler:
        yield from file_handler


data_reader: FileReader = file_reader


@dataclass
class Button:
    x: int | None = None
    y: int | None = None

    def decode_button(self, code: str):
        x, y = code.split(",")
        _, x = x.strip().split("+")
        _, y = y.strip().split("+")
        self.x = int(x)
        self.y = int(y)


@dataclass
class Prize:
    x: int | None = None
    y: int | None = None

    def decode_prize(self, code: str):
        x, y = code.split(",")
        _, x = x.strip().split("=")
        _, y = y.strip().split("=")
        self.x = int(x)
        self.y = int(y)


@dataclass
class Task:
    button_a: Button | None = None
    button_b: Button | None = None
    prize: Prize | None = None

    def is_complete(self) -> bool:
        if all([self.button_a, self.button_b, self.prize]):
            return True
        return False

    def resolve(self) -> int:
        """An efficient solution of a system of two linear equations
        with two unknowns in integers (called a Diophantine system) can be solved
        in two steps.

        :return:
            a price to reach the prize
        """
        x1 = self.button_a.x
        x2 = self.button_b.x
        xp = self.prize.x
        y1 = self.button_a.y
        y2 = self.button_b.y
        yp = self.prize.y
        
        D = x1 * y2 - x2 * y1
        C = yp * x1 - xp * y1

        if D == 0 or C % D != 0:
            return 0

        b = C // D
        a = (xp - b * x2) // x1
        return a * 3 + b * 1


@dataclass
class Tasks:
    items: list[Task] = field(default_factory=list)

    def resolve(self) -> int:
        value: int = 0
        for task in self.items:
            value += task.resolve()

        return value

    def load_from_file(self, file_path: FilePath):
        current_task: Task = Task()
        self.items.append(current_task)
        for line in data_reader(file_path):
            try:
                subject, value = line.split(":")
            except ValueError:
                subject, value = "default", None
            match subject:
                case "Button A":
                    current_task.button_a = Button()
                    current_task.button_a.decode_button(value)
                case "Button B":
                    current_task.button_b = Button()
                    current_task.button_b.decode_button(value)
                case "Prize":
                    current_task.prize = Prize()
                    current_task.prize.decode_prize(value)
                case _:
                    if current_task.is_complete():
                        current_task = Task()
                        self.items.append(current_task)

# %%
from rich import print


tasks: Tasks = Tasks()
tasks.load_from_file("../media/2024-day-13.input")

print(tasks)

print(tasks.resolve())
# Out:
# Tasks(
#     items=[
#         Task(button_a=Button(x=62, y=54), button_b=Button(x=19, y=93), prize=Prize(x=4094, y=11058)),
#         Task(button_a=Button(x=55, y=93), button_b=Button(x=83, y=27), prize=Prize(x=9995, y=7833)),
#         Task(button_a=Button(x=83, y=31), button_b=Button(x=21, y=34), prize=Prize(x=8042, y=4233)),
#         Task(button_a=Button(x=21, y=11), button_b=Button(x=11, y=23), prize=Prize(x=13963, y=17749)),
#         Task(button_a=Button(x=65, y=97), button_b=Button(x=83, y=12), prize=Prize(x=6919, y=3278)),
#         Task(button_a=Button(x=28, y=17), button_b=Button(x=16, y=43), prize=Prize(x=19828, y=14869)),
#         Task(button_a=Button(x=26, y=12), button_b=Button(x=40, y=59), prize=Prize(x=19660, y=1040)),
#         Task(button_a=Button(x=17, y=80), button_b=Button(x=77, y=16), prize=Prize(x=11125, y=19344)),
#         Task(button_a=Button(x=41, y=77), button_b=Button(x=97, y=15), prize=Prize(x=6430, y=4386)),
#         Task(button_a=Button(x=18, y=58), button_b=Button(x=68, y=24), prize=Prize(x=3136, y=3276)),
#         Task(button_a=Button(x=40, y=39), button_b=Button(x=21, y=98), prize=Prize(x=2893, y=8480)),
#         Task(button_a=Button(x=57, y=11), button_b=Button(x=42, y=99), prize=Prize(x=7356, y=6237)),
#         Task(button_a=Button(x=21, y=61), button_b=Button(x=72, y=24), prize=Prize(x=7049, y=5889)),
#         Task(button_a=Button(x=55, y=21), button_b=Button(x=20, y=37), prize=Prize(x=17600, y=18892)),
#         Task(button_a=Button(x=39, y=79), button_b=Button(x=51, y=14), prize=Prize(x=11165, y=15493)),
#         Task(button_a=Button(x=59, y=97), button_b=Button(x=35, y=19), prize=Prize(x=1331, y=1957)),
#         Task(button_a=Button(x=65, y=21), button_b=Button(x=23, y=54), prize=Prize(x=8456, y=3041)),
#         Task(button_a=Button(x=29, y=52), button_b=Button(x=42, y=17), prize=Prize(x=7340, y=17904)),
#         Task(button_a=Button(x=97, y=15), button_b=Button(x=78, y=75), prize=Prize(x=10291, y=6060)),
#         Task(button_a=Button(x=14, y=48), button_b=Button(x=49, y=26), prize=Prize(x=18015, y=4490)),
#         Task(button_a=Button(x=47, y=16), button_b=Button(x=38, y=68), prize=Prize(x=4834, y=6688)),
#         Task(button_a=Button(x=76, y=19), button_b=Button(x=16, y=62), prize=Prize(x=18040, y=6100)),
#         Task(button_a=Button(x=15, y=43), button_b=Button(x=44, y=15), prize=Prize(x=18354, y=6234)),
#         Task(button_a=Button(x=27, y=73), button_b=Button(x=63, y=20), prize=Prize(x=18080, y=2029)),
#         Task(button_a=Button(x=52, y=78), button_b=Button(x=73, y=31), prize=Prize(x=6369, y=3823)),
#         Task(button_a=Button(x=16, y=55), button_b=Button(x=33, y=16), prize=Prize(x=19647, y=4165)),
#         Task(button_a=Button(x=23, y=17), button_b=Button(x=37, y=86), prize=Prize(x=2569, y=3893)),
#         Task(button_a=Button(x=18, y=57), button_b=Button(x=70, y=17), prize=Prize(x=10998, y=4825)),
#         Task(button_a=Button(x=16, y=31), button_b=Button(x=61, y=36), prize=Prize(x=262, y=11902)),
#         Task(button_a=Button(x=48, y=27), button_b=Button(x=13, y=43), prize=Prize(x=6877, y=7117)),
#         Task(button_a=Button(x=13, y=36), button_b=Button(x=49, y=27), prize=Prize(x=5930, y=12113)),
#         Task(button_a=Button(x=62, y=21), button_b=Button(x=31, y=76), prize=Prize(x=3184, y=1310)),
#         Task(button_a=Button(x=55, y=13), button_b=Button(x=33, y=83), prize=Prize(x=11298, y=1134)),
#         Task(button_a=Button(x=68, y=13), button_b=Button(x=63, y=92), prize=Prize(x=2972, y=888)),
#         Task(button_a=Button(x=18, y=24), button_b=Button(x=71, y=11), prize=Prize(x=6903, y=2427)),
#         Task(button_a=Button(x=84, y=17), button_b=Button(x=40, y=53), prize=Prize(x=4860, y=1253)),
#         Task(button_a=Button(x=74, y=39), button_b=Button(x=17, y=51), prize=Prize(x=5051, y=6797)),
#         Task(button_a=Button(x=65, y=18), button_b=Button(x=24, y=76), prize=Prize(x=9457, y=8214)),
#         Task(button_a=Button(x=66, y=22), button_b=Button(x=14, y=43), prize=Prize(x=810, y=14750)),
#         Task(button_a=Button(x=12, y=82), button_b=Button(x=93, y=70), prize=Prize(x=3672, y=9258)),
#         Task(button_a=Button(x=63, y=26), button_b=Button(x=35, y=56), prize=Prize(x=3948, y=3998)),
#         Task(button_a=Button(x=51, y=25), button_b=Button(x=28, y=54), prize=Prize(x=3832, y=4456)),
#         Task(button_a=Button(x=24, y=62), button_b=Button(x=67, y=33), prize=Prize(x=14082, y=8066)),
#         Task(button_a=Button(x=33, y=15), button_b=Button(x=28, y=54), prize=Prize(x=4793, y=1049)),
#         Task(button_a=Button(x=58, y=25), button_b=Button(x=27, y=60), prize=Prize(x=5684, y=3440)),
#         Task(button_a=Button(x=51, y=27), button_b=Button(x=12, y=33), prize=Prize(x=6641, y=12200)),
#         Task(button_a=Button(x=91, y=41), button_b=Button(x=39, y=93), prize=Prize(x=9633, y=11355)),
#         Task(button_a=Button(x=16, y=41), button_b=Button(x=60, y=19), prize=Prize(x=11624, y=17434)),
#         Task(button_a=Button(x=23, y=62), button_b=Button(x=70, y=33), prize=Prize(x=6285, y=5378)),
#         Task(button_a=Button(x=63, y=38), button_b=Button(x=24, y=52), prize=Prize(x=18713, y=4086)),
#         Task(button_a=Button(x=92, y=17), button_b=Button(x=44, y=96), prize=Prize(x=6932, y=9980)),
#         Task(button_a=Button(x=92, y=99), button_b=Button(x=99, y=17), prize=Prize(x=9724, y=2585)),
#         Task(button_a=Button(x=95, y=16), button_b=Button(x=63, y=62), prize=Prize(x=11570, y=5032)),
#         Task(button_a=Button(x=49, y=18), button_b=Button(x=18, y=28), prize=Prize(x=5064, y=2288)),
#         Task(button_a=Button(x=35, y=77), button_b=Button(x=53, y=14), prize=Prize(x=16536, y=13857)),
#         Task(button_a=Button(x=14, y=41), button_b=Button(x=89, y=71), prize=Prize(x=8902, y=8623)),
#         Task(button_a=Button(x=49, y=17), button_b=Button(x=27, y=70), prize=Prize(x=18325, y=2157)),
#         Task(button_a=Button(x=20, y=57), button_b=Button(x=54, y=18), prize=Prize(x=19442, y=3419)),
#         Task(button_a=Button(x=11, y=25), button_b=Button(x=72, y=42), prize=Prize(x=8781, y=6799)),
#         Task(button_a=Button(x=20, y=48), button_b=Button(x=61, y=37), prize=Prize(x=10609, y=5109)),
#         Task(button_a=Button(x=19, y=45), button_b=Button(x=42, y=12), prize=Prize(x=253, y=1835)),
#         Task(button_a=Button(x=15, y=48), button_b=Button(x=64, y=16), prize=Prize(x=17517, y=13728)),
#         Task(button_a=Button(x=52, y=13), button_b=Button(x=25, y=66), prize=Prize(x=8798, y=10188)),
#         Task(button_a=Button(x=20, y=46), button_b=Button(x=51, y=30), prize=Prize(x=12086, y=9494)),
#         Task(button_a=Button(x=21, y=58), button_b=Button(x=63, y=22), prize=Prize(x=17063, y=1590)),
#         Task(button_a=Button(x=11, y=39), button_b=Button(x=75, y=30), prize=Prize(x=2732, y=8453)),
#         Task(button_a=Button(x=57, y=26), button_b=Button(x=26, y=47), prize=Prize(x=16605, y=523)),
#         Task(button_a=Button(x=64, y=21), button_b=Button(x=18, y=80), prize=Prize(x=2504, y=5860)),
#         Task(button_a=Button(x=83, y=15), button_b=Button(x=56, y=57), prize=Prize(x=4586, y=4251)),
#         Task(button_a=Button(x=33, y=13), button_b=Button(x=27, y=58), prize=Prize(x=12359, y=17846)),
#         Task(button_a=Button(x=19, y=39), button_b=Button(x=59, y=19), prize=Prize(x=7183, y=19763)),
#         Task(button_a=Button(x=17, y=11), button_b=Button(x=22, y=49), prize=Prize(x=9203, y=17789)),
#         Task(button_a=Button(x=28, y=99), button_b=Button(x=87, y=11), prize=Prize(x=2165, y=6765)),
#         Task(button_a=Button(x=69, y=28), button_b=Button(x=52, y=70), prize=Prize(x=10406, y=8428)),
#         Task(button_a=Button(x=30, y=12), button_b=Button(x=53, y=76), prize=Prize(x=13030, y=14808)),
#         Task(button_a=Button(x=17, y=49), button_b=Button(x=47, y=28), prize=Prize(x=9223, y=9615)),
#         Task(button_a=Button(x=33, y=34), button_b=Button(x=76, y=15), prize=Prize(x=2661, y=1982)),
#         Task(button_a=Button(x=19, y=50), button_b=Button(x=44, y=15), prize=Prize(x=8425, y=17470)),
#         Task(button_a=Button(x=80, y=45), button_b=Button(x=17, y=65), prize=Prize(x=3863, y=4335)),
#         Task(button_a=Button(x=27, y=16), button_b=Button(x=14, y=28), prize=Prize(x=8861, y=17640)),
#         Task(button_a=Button(x=32, y=91), button_b=Button(x=61, y=52), prize=Prize(x=5445, y=10504)),
#         Task(button_a=Button(x=13, y=42), button_b=Button(x=58, y=38), prize=Prize(x=6888, y=14140)),
#         Task(button_a=Button(x=25, y=61), button_b=Button(x=40, y=11), prize=Prize(x=1375, y=16891)),
#         Task(button_a=Button(x=11, y=52), button_b=Button(x=75, y=29), prize=Prize(x=4368, y=12074)),
#         Task(button_a=Button(x=22, y=53), button_b=Button(x=56, y=29), prize=Prize(x=7670, y=8250)),
#         Task(button_a=Button(x=32, y=11), button_b=Button(x=32, y=68), prize=Prize(x=7360, y=16987)),
#         Task(button_a=Button(x=18, y=46), button_b=Button(x=33, y=16), prize=Prize(x=3564, y=2548)),
#         Task(button_a=Button(x=11, y=46), button_b=Button(x=54, y=32), prize=Prize(x=10843, y=10358)),
#         Task(button_a=Button(x=60, y=83), button_b=Button(x=32, y=13), prize=Prize(x=16748, y=18281)),
#         Task(button_a=Button(x=32, y=59), button_b=Button(x=97, y=19), prize=Prize(x=6823, y=6346)),
#         Task(button_a=Button(x=96, y=60), button_b=Button(x=47, y=94), prize=Prize(x=9828, y=10020)),
#         Task(button_a=Button(x=12, y=72), button_b=Button(x=81, y=86), prize=Prize(x=3333, y=8398)),
#         Task(button_a=Button(x=59, y=30), button_b=Button(x=54, y=97), prize=Prize(x=7038, y=5804)),
#         Task(button_a=Button(x=21, y=45), button_b=Button(x=48, y=27), prize=Prize(x=12056, y=269)),
#         Task(button_a=Button(x=80, y=31), button_b=Button(x=30, y=82), prize=Prize(x=4020, y=5921)),
#         Task(button_a=Button(x=80, y=35), button_b=Button(x=25, y=55), prize=Prize(x=6620, y=4130)),
#         Task(button_a=Button(x=31, y=18), button_b=Button(x=13, y=31), prize=Prize(x=15898, y=6859)),
#         Task(button_a=Button(x=80, y=30), button_b=Button(x=20, y=43), prize=Prize(x=5820, y=3283)),
#         Task(button_a=Button(x=13, y=27), button_b=Button(x=34, y=15), prize=Prize(x=17252, y=377)),
#         Task(button_a=Button(x=49, y=11), button_b=Button(x=40, y=76), prize=Prize(x=16449, y=15823)),
#         Task(button_a=Button(x=92, y=32), button_b=Button(x=28, y=48), prize=Prize(x=7096, y=2736)),
#         Task(button_a=Button(x=22, y=76), button_b=Button(x=54, y=13), prize=Prize(x=19030, y=18217)),
#         Task(button_a=Button(x=98, y=24), button_b=Button(x=56, y=62), prize=Prize(x=1162, y=864)),
#         Task(button_a=Button(x=32, y=80), button_b=Button(x=72, y=45), prize=Prize(x=4448, y=7340)),
#         Task(button_a=Button(x=45, y=16), button_b=Button(x=14, y=27), prize=Prize(x=13215, y=3378)),
#         Task(button_a=Button(x=13, y=25), button_b=Button(x=34, y=19), prize=Prize(x=8660, y=3962)),
#         Task(button_a=Button(x=78, y=32), button_b=Button(x=12, y=61), prize=Prize(x=14312, y=6693)),
#         Task(button_a=Button(x=17, y=72), button_b=Button(x=53, y=53), prize=Prize(x=1650, y=5445)),
#         Task(button_a=Button(x=99, y=51), button_b=Button(x=12, y=53), prize=Prize(x=10587, y=9293)),
#         Task(button_a=Button(x=19, y=62), button_b=Button(x=72, y=52), prize=Prize(x=6359, y=8310)),
#         Task(button_a=Button(x=75, y=31), button_b=Button(x=13, y=40), prize=Prize(x=8828, y=551)),
#         Task(button_a=Button(x=64, y=14), button_b=Button(x=26, y=42), prize=Prize(x=6138, y=3122)),
#         Task(button_a=Button(x=23, y=89), button_b=Button(x=92, y=15), prize=Prize(x=10143, y=5490)),
#         Task(button_a=Button(x=19, y=45), button_b=Button(x=71, y=52), prize=Prize(x=1728, y=1421)),
#         Task(button_a=Button(x=72, y=19), button_b=Button(x=32, y=62), prize=Prize(x=8328, y=4929)),
#         Task(button_a=Button(x=15, y=77), button_b=Button(x=44, y=11), prize=Prize(x=16875, y=8812)),
#         Task(button_a=Button(x=13, y=66), button_b=Button(x=82, y=31), prize=Prize(x=10424, y=874)),
#         Task(button_a=Button(x=53, y=27), button_b=Button(x=36, y=58), prize=Prize(x=1610, y=2010)),
#         Task(button_a=Button(x=16, y=82), button_b=Button(x=71, y=16), prize=Prize(x=6923, y=8694)),
#         Task(button_a=Button(x=95, y=73), button_b=Button(x=13, y=61), prize=Prize(x=8506, y=10464)),
#         Task(button_a=Button(x=78, y=23), button_b=Button(x=12, y=59), prize=Prize(x=4266, y=4031)),
#         Task(button_a=Button(x=31, y=87), button_b=Button(x=71, y=36), prize=Prize(x=1330, y=2100)),
#         Task(button_a=Button(x=15, y=55), button_b=Button(x=38, y=13), prize=Prize(x=16129, y=12049)),
#         Task(button_a=Button(x=74, y=18), button_b=Button(x=14, y=50), prize=Prize(x=6380, y=1904)),
#         Task(button_a=Button(x=36, y=19), button_b=Button(x=13, y=31), prize=Prize(x=13245, y=15500)),
#         Task(button_a=Button(x=37, y=16), button_b=Button(x=18, y=33), prize=Prize(x=13068, y=10692)),
#         Task(button_a=Button(x=56, y=20), button_b=Button(x=29, y=62), prize=Prize(x=5211, y=3462)),
#         Task(button_a=Button(x=26, y=59), button_b=Button(x=45, y=19), prize=Prize(x=399, y=7100)),
#         Task(button_a=Button(x=52, y=14), button_b=Button(x=25, y=77), prize=Prize(x=2490, y=9454)),
#         Task(button_a=Button(x=42, y=11), button_b=Button(x=20, y=36), prize=Prize(x=9786, y=1137)),
#         Task(button_a=Button(x=61, y=14), button_b=Button(x=49, y=93), prize=Prize(x=6529, y=7303)),
#         Task(button_a=Button(x=27, y=17), button_b=Button(x=12, y=41), prize=Prize(x=11438, y=1948)),
#         Task(button_a=Button(x=53, y=11), button_b=Button(x=54, y=88), prize=Prize(x=5465, y=5665)),
#         Task(button_a=Button(x=15, y=77), button_b=Button(x=78, y=18), prize=Prize(x=4700, y=10332)),
#         Task(button_a=Button(x=11, y=59), button_b=Button(x=48, y=19), prize=Prize(x=15210, y=9409)),
#         Task(button_a=Button(x=16, y=52), button_b=Button(x=41, y=17), prize=Prize(x=8584, y=11248)),
#         Task(button_a=Button(x=56, y=13), button_b=Button(x=29, y=68), prize=Prize(x=2453, y=17869)),
#         Task(button_a=Button(x=35, y=91), button_b=Button(x=76, y=17), prize=Prize(x=3918, y=6033)),
#         Task(button_a=Button(x=77, y=57), button_b=Button(x=21, y=50), prize=Prize(x=5152, y=6708)),
#         Task(button_a=Button(x=91, y=83), button_b=Button(x=75, y=12), prize=Prize(x=12690, y=8190)),
#         Task(button_a=Button(x=14, y=55), button_b=Button(x=73, y=19), prize=Prize(x=11601, y=15256)),
#         Task(button_a=Button(x=50, y=22), button_b=Button(x=15, y=90), prize=Prize(x=5055, y=5310)),
#         Task(button_a=Button(x=18, y=89), button_b=Button(x=68, y=44), prize=Prize(x=3436, y=7638)),
#         Task(button_a=Button(x=39, y=17), button_b=Button(x=33, y=62), prize=Prize(x=3546, y=5593)),
#         Task(button_a=Button(x=12, y=37), button_b=Button(x=69, y=37), prize=Prize(x=14282, y=9906)),
#         Task(button_a=Button(x=63, y=14), button_b=Button(x=12, y=59), prize=Prize(x=13250, y=17592)),
#         Task(button_a=Button(x=36, y=13), button_b=Button(x=11, y=27), prize=Prize(x=2067, y=13051)),
#         Task(button_a=Button(x=20, y=41), button_b=Button(x=66, y=12), prize=Prize(x=5388, y=3894)),
#         Task(button_a=Button(x=20, y=56), button_b=Button(x=67, y=13), prize=Prize(x=19450, y=8218)),
#         Task(button_a=Button(x=78, y=54), button_b=Button(x=12, y=79), prize=Prize(x=1170, y=6324)),
#         Task(button_a=Button(x=90, y=18), button_b=Button(x=85, y=85), prize=Prize(x=3190, y=2542)),
#         Task(button_a=Button(x=41, y=55), button_b=Button(x=33, y=11), prize=Prize(x=4748, y=13212)),
#         Task(button_a=Button(x=14, y=32), button_b=Button(x=71, y=43), prize=Prize(x=7996, y=7508)),
#         Task(button_a=Button(x=21, y=62), button_b=Button(x=29, y=12), prize=Prize(x=9063, y=14936)),
#         Task(button_a=Button(x=22, y=62), button_b=Button(x=55, y=16), prize=Prize(x=2156, y=4130)),
#         Task(button_a=Button(x=59, y=14), button_b=Button(x=74, y=83), prize=Prize(x=12057, y=8358)),
#         Task(button_a=Button(x=14, y=37), button_b=Button(x=76, y=19), prize=Prize(x=5898, y=2312)),
#         Task(button_a=Button(x=91, y=15), button_b=Button(x=59, y=69), prize=Prize(x=3305, y=1671)),
#         Task(button_a=Button(x=15, y=37), button_b=Button(x=49, y=36), prize=Prize(x=7184, y=9695)),
#         Task(button_a=Button(x=20, y=41), button_b=Button(x=43, y=18), prize=Prize(x=463, y=10089)),
#         Task(button_a=Button(x=94, y=44), button_b=Button(x=30, y=82), prize=Prize(x=7600, y=5868)),
#         Task(button_a=Button(x=96, y=13), button_b=Button(x=32, y=33), prize=Prize(x=3424, y=693)),
#         Task(button_a=Button(x=36, y=68), button_b=Button(x=79, y=14), prize=Prize(x=7294, y=4312)),
#         Task(button_a=Button(x=20, y=68), button_b=Button(x=60, y=23), prize=Prize(x=8420, y=15573)),
#         Task(button_a=Button(x=27, y=74), button_b=Button(x=62, y=17), prize=Prize(x=3968, y=16866)),
#         Task(button_a=Button(x=73, y=29), button_b=Button(x=17, y=45), prize=Prize(x=3900, y=5444)),
#         Task(button_a=Button(x=27, y=52), button_b=Button(x=36, y=12), prize=Prize(x=693, y=876)),
#         Task(button_a=Button(x=37, y=18), button_b=Button(x=31, y=51), prize=Prize(x=6019, y=18734)),
#         Task(button_a=Button(x=29, y=76), button_b=Button(x=42, y=13), prize=Prize(x=11614, y=2906)),
#         Task(button_a=Button(x=14, y=42), button_b=Button(x=59, y=35), prize=Prize(x=18349, y=11813)),
#         Task(button_a=Button(x=68, y=48), button_b=Button(x=39, y=92), prize=Prize(x=6801, y=9636)),
#         Task(button_a=Button(x=25, y=41), button_b=Button(x=75, y=35), prize=Prize(x=7025, y=4481)),
#         Task(button_a=Button(x=64, y=37), button_b=Button(x=11, y=21), prize=Prize(x=6001, y=11072)),
#         Task(button_a=Button(x=58, y=26), button_b=Button(x=28, y=70), prize=Prize(x=6296, y=7648)),
#         Task(button_a=Button(x=14, y=53), button_b=Button(x=81, y=42), prize=Prize(x=6345, y=17070)),
#         Task(button_a=Button(x=14, y=42), button_b=Button(x=62, y=18), prize=Prize(x=2166, y=18194)),
#         Task(button_a=Button(x=20, y=75), button_b=Button(x=48, y=33), prize=Prize(x=2368, y=5058)),
#         Task(button_a=Button(x=25, y=46), button_b=Button(x=47, y=19), prize=Prize(x=13106, y=17558)),
#         Task(button_a=Button(x=44, y=16), button_b=Button(x=45, y=82), prize=Prize(x=3277, y=2570)),
#         Task(button_a=Button(x=86, y=30), button_b=Button(x=21, y=91), prize=Prize(x=4067, y=8029)),
#         Task(button_a=Button(x=31, y=80), button_b=Button(x=85, y=38), prize=Prize(x=4335, y=7560)),
#         Task(button_a=Button(x=61, y=23), button_b=Button(x=17, y=47), prize=Prize(x=4852, y=2260)),
#         Task(button_a=Button(x=60, y=15), button_b=Button(x=21, y=57), prize=Prize(x=13505, y=1985)),
#         Task(button_a=Button(x=36, y=16), button_b=Button(x=27, y=43), prize=Prize(x=16037, y=9885)),
#         Task(button_a=Button(x=46, y=13), button_b=Button(x=21, y=66), prize=Prize(x=13369, y=6940)),
#         Task(button_a=Button(x=14, y=45), button_b=Button(x=26, y=16), prize=Prize(x=9320, y=13990)),
#         Task(button_a=Button(x=14, y=26), button_b=Button(x=92, y=25), prize=Prize(x=8294, y=4318)),
#         Task(button_a=Button(x=53, y=19), button_b=Button(x=14, y=26), prize=Prize(x=16384, y=10312)),
#         Task(button_a=Button(x=52, y=75), button_b=Button(x=63, y=26), prize=Prize(x=6045, y=2816)),
#         Task(button_a=Button(x=15, y=43), button_b=Button(x=71, y=23), prize=Prize(x=16775, y=9495)),
#         Task(button_a=Button(x=69, y=33), button_b=Button(x=40, y=99), prize=Prize(x=6091, y=4191)),
#         Task(button_a=Button(x=99, y=32), button_b=Button(x=36, y=51), prize=Prize(x=7065, y=5787)),
#         Task(button_a=Button(x=47, y=70), button_b=Button(x=60, y=26), prize=Prize(x=2586, y=2014)),
#         Task(button_a=Button(x=91, y=27), button_b=Button(x=31, y=68), prize=Prize(x=8982, y=8310)),
#         Task(button_a=Button(x=93, y=45), button_b=Button(x=32, y=62), prize=Prize(x=2799, y=1773)),
#         Task(button_a=Button(x=19, y=38), button_b=Button(x=45, y=13), prize=Prize(x=13235, y=531)),
#         Task(button_a=Button(x=25, y=44), button_b=Button(x=59, y=27), prize=Prize(x=5501, y=2843)),
#         Task(button_a=Button(x=18, y=36), button_b=Button(x=68, y=43), prize=Prize(x=2396, y=13667)),
#         Task(button_a=Button(x=67, y=31), button_b=Button(x=16, y=61), prize=Prize(x=9339, y=13839)),
#         Task(button_a=Button(x=50, y=18), button_b=Button(x=59, y=94), prize=Prize(x=7668, y=6544)),
#         Task(button_a=Button(x=76, y=12), button_b=Button(x=56, y=66), prize=Prize(x=7032, y=6426)),
#         Task(button_a=Button(x=14, y=37), button_b=Button(x=65, y=35), prize=Prize(x=13499, y=18892)),
#         Task(button_a=Button(x=17, y=35), button_b=Button(x=21, y=12), prize=Prize(x=4779, y=16569)),
#         Task(button_a=Button(x=35, y=41), button_b=Button(x=83, y=16), prize=Prize(x=4487, y=1276)),
#         Task(button_a=Button(x=39, y=37), button_b=Button(x=95, y=15), prize=Prize(x=6688, y=2814)),
#         Task(button_a=Button(x=26, y=55), button_b=Button(x=35, y=15), prize=Prize(x=8743, y=6110)),
#         Task(button_a=Button(x=42, y=34), button_b=Button(x=22, y=75), prize=Prize(x=958, y=2720)),
#         Task(button_a=Button(x=67, y=20), button_b=Button(x=18, y=60), prize=Prize(x=14996, y=6200)),
#         Task(button_a=Button(x=13, y=49), button_b=Button(x=68, y=33), prize=Prize(x=17288, y=1213)),
#         Task(button_a=Button(x=13, y=56), button_b=Button(x=67, y=31), prize=Prize(x=4233, y=3808)),
#         Task(button_a=Button(x=65, y=17), button_b=Button(x=13, y=45), prize=Prize(x=7790, y=14958)),
#         Task(button_a=Button(x=42, y=17), button_b=Button(x=11, y=44), prize=Prize(x=18067, y=5940)),
#         Task(button_a=Button(x=14, y=40), button_b=Button(x=49, y=11), prize=Prize(x=5873, y=4009)),
#         Task(button_a=Button(x=70, y=27), button_b=Button(x=26, y=42), prize=Prize(x=9094, y=6513)),
#         Task(button_a=Button(x=58, y=31), button_b=Button(x=16, y=30), prize=Prize(x=2210, y=10445)),
#         Task(button_a=Button(x=38, y=79), button_b=Button(x=80, y=54), prize=Prize(x=10226, y=10477)),
#         Task(button_a=Button(x=61, y=51), button_b=Button(x=34, y=96), prize=Prize(x=1296, y=1962)),
#         Task(button_a=Button(x=66, y=24), button_b=Button(x=60, y=83), prize=Prize(x=5970, y=7249)),
#         Task(button_a=Button(x=77, y=33), button_b=Button(x=15, y=56), prize=Prize(x=5348, y=10861)),
#         Task(button_a=Button(x=97, y=16), button_b=Button(x=15, y=75), prize=Prize(x=3718, y=2644)),
#         Task(button_a=Button(x=18, y=66), button_b=Button(x=57, y=23), prize=Prize(x=1331, y=461)),
#         Task(button_a=Button(x=86, y=19), button_b=Button(x=11, y=68), prize=Prize(x=11493, y=13480)),
#         Task(button_a=Button(x=58, y=19), button_b=Button(x=27, y=65), prize=Prize(x=4463, y=3989)),
#         Task(button_a=Button(x=22, y=99), button_b=Button(x=58, y=47), prize=Prize(x=4658, y=9619)),
#         Task(button_a=Button(x=41, y=77), button_b=Button(x=83, y=15), prize=Prize(x=3826, y=5354)),
#         Task(button_a=Button(x=61, y=87), button_b=Button(x=88, y=23), prize=Prize(x=9185, y=7872)),
#         Task(button_a=Button(x=29, y=85), button_b=Button(x=92, y=70), prize=Prize(x=1756, y=3350)),
#         Task(button_a=Button(x=34, y=14), button_b=Button(x=34, y=53), prize=Prize(x=9560, y=6383)),
#         Task(button_a=Button(x=58, y=22), button_b=Button(x=27, y=57), prize=Prize(x=3229, y=11191)),
#         Task(button_a=Button(x=23, y=11), button_b=Button(x=24, y=63), prize=Prize(x=17926, y=17857)),
#         Task(button_a=Button(x=13, y=73), button_b=Button(x=99, y=22), prize=Prize(x=979, y=1760)),
#         Task(button_a=Button(x=85, y=14), button_b=Button(x=69, y=68), prize=Prize(x=3893, y=1604)),
#         Task(button_a=Button(x=35, y=70), button_b=Button(x=48, y=13), prize=Prize(x=13198, y=8123)),
#         Task(button_a=Button(x=19, y=48), button_b=Button(x=41, y=17), prize=Prize(x=12712, y=4069)),
#         Task(button_a=Button(x=76, y=29), button_b=Button(x=74, y=98), prize=Prize(x=2248, y=1974)),
#         Task(button_a=Button(x=18, y=60), button_b=Button(x=36, y=33), prize=Prize(x=4716, y=7716)),
#         Task(button_a=Button(x=13, y=38), button_b=Button(x=35, y=21), prize=Prize(x=15360, y=18553)),
#         Task(button_a=Button(x=30, y=86), button_b=Button(x=79, y=47), prize=Prize(x=8027, y=8115)),
#         Task(button_a=Button(x=29, y=11), button_b=Button(x=43, y=59), prize=Prize(x=9067, y=12323)),
#         Task(button_a=Button(x=37, y=12), button_b=Button(x=13, y=37), prize=Prize(x=5632, y=200)),
#         Task(button_a=Button(x=83, y=20), button_b=Button(x=19, y=72), prize=Prize(x=6469, y=6548)),
#         Task(button_a=Button(x=65, y=20), button_b=Button(x=21, y=61), prize=Prize(x=16475, y=4040)),
#         Task(button_a=Button(x=44, y=14), button_b=Button(x=36, y=78), prize=Prize(x=5748, y=16506)),
#         Task(button_a=Button(x=30, y=11), button_b=Button(x=20, y=57), prize=Prize(x=14450, y=18684)),
#         Task(button_a=Button(x=67, y=19), button_b=Button(x=22, y=72), prize=Prize(x=13334, y=18046)),
#         Task(button_a=Button(x=44, y=46), button_b=Button(x=85, y=16), prize=Prize(x=4389, y=2184)),
#         Task(button_a=Button(x=61, y=28), button_b=Button(x=24, y=62), prize=Prize(x=9152, y=946)),
#         Task(button_a=Button(x=62, y=11), button_b=Button(x=30, y=63), prize=Prize(x=6224, y=5084)),
#         Task(button_a=Button(x=60, y=33), button_b=Button(x=15, y=28), prize=Prize(x=16985, y=17028)),
#         Task(button_a=Button(x=17, y=45), button_b=Button(x=45, y=26), prize=Prize(x=12775, y=255)),
#         Task(button_a=Button(x=32, y=52), button_b=Button(x=39, y=14), prize=Prize(x=16202, y=7912)),
#         Task(button_a=Button(x=51, y=11), button_b=Button(x=90, y=96), prize=Prize(x=2856, y=1918)),
#         Task(button_a=Button(x=55, y=14), button_b=Button(x=21, y=59), prize=Prize(x=7579, y=18566)),
#         Task(button_a=Button(x=20, y=45), button_b=Button(x=47, y=32), prize=Prize(x=6786, y=15691)),
#         Task(button_a=Button(x=83, y=59), button_b=Button(x=11, y=83), prize=Prize(x=1447, y=4111)),
#         Task(button_a=Button(x=70, y=23), button_b=Button(x=16, y=59), prize=Prize(x=14404, y=585)),
#         Task(button_a=Button(x=20, y=50), button_b=Button(x=55, y=28), prize=Prize(x=9160, y=1204)),
#         Task(button_a=Button(x=68, y=55), button_b=Button(x=12, y=42), prize=Prize(x=3188, y=3838)),
#         Task(button_a=Button(x=69, y=80), button_b=Button(x=11, y=89), prize=Prize(x=5158, y=6819)),
#         Task(button_a=Button(x=29, y=61), button_b=Button(x=55, y=13), prize=Prize(x=3197, y=8483)),
#         Task(button_a=Button(x=74, y=25), button_b=Button(x=11, y=56), prize=Prize(x=12703, y=15991)),
#         Task(button_a=Button(x=60, y=15), button_b=Button(x=42, y=95), prize=Prize(x=4998, y=9615)),
#         Task(button_a=Button(x=23, y=32), button_b=Button(x=87, y=34), prize=Prize(x=10409, y=6300)),
#         Task(button_a=Button(x=11, y=44), button_b=Button(x=71, y=24), prize=Prize(x=13268, y=17872)),
#         Task(button_a=Button(x=13, y=60), button_b=Button(x=63, y=22), prize=Prize(x=6522, y=5106)),
#         Task(button_a=Button(x=87, y=32), button_b=Button(x=11, y=66), prize=Prize(x=4834, y=4504)),
#         Task(button_a=Button(x=55, y=22), button_b=Button(x=21, y=52), prize=Prize(x=11757, y=2214)),
#         Task(button_a=Button(x=28, y=69), button_b=Button(x=37, y=13), prize=Prize(x=3138, y=17965)),
#         Task(button_a=Button(x=77, y=13), button_b=Button(x=19, y=30), prize=Prize(x=4100, y=2782)),
#         Task(button_a=Button(x=29, y=55), button_b=Button(x=49, y=27), prize=Prize(x=17241, y=12611)),
#         Task(button_a=Button(x=23, y=13), button_b=Button(x=23, y=75), prize=Prize(x=3427, y=7703)),
#         Task(button_a=Button(x=43, y=32), button_b=Button(x=17, y=55), prize=Prize(x=907, y=1649)),
#         Task(button_a=Button(x=20, y=71), button_b=Button(x=65, y=39), prize=Prize(x=6270, y=5768)),
#         Task(button_a=Button(x=11, y=58), button_b=Button(x=81, y=17), prize=Prize(x=330, y=17911)),
#         Task(button_a=Button(x=22, y=31), button_b=Button(x=54, y=16), prize=Prize(x=4142, y=1570)),
#         Task(button_a=Button(x=25, y=79), button_b=Button(x=68, y=12), prize=Prize(x=19174, y=458)),
#         Task(button_a=Button(x=15, y=55), button_b=Button(x=47, y=18), prize=Prize(x=6941, y=19714)),
#         Task(button_a=Button(x=60, y=30), button_b=Button(x=48, y=77), prize=Prize(x=4812, y=5533)),
#         Task(button_a=Button(x=71, y=48), button_b=Button(x=15, y=61), prize=Prize(x=2520, y=3026)),
#         Task(button_a=Button(x=26, y=12), button_b=Button(x=18, y=29), prize=Prize(x=3506, y=16969)),
#         Task(button_a=Button(x=16, y=80), button_b=Button(x=82, y=39), prize=Prize(x=8130, y=10599)),
#         Task(button_a=Button(x=32, y=79), button_b=Button(x=89, y=36), prize=Prize(x=8654, y=4095)),
#         Task(button_a=Button(x=28, y=75), button_b=Button(x=85, y=60), prize=Prize(x=2856, y=2955)),
#         Task(button_a=Button(x=91, y=51), button_b=Button(x=20, y=68), prize=Prize(x=9032, y=6936)),
#         Task(button_a=Button(x=36, y=80), button_b=Button(x=43, y=12), prize=Prize(x=14547, y=14252)),
#         Task(button_a=Button(x=95, y=16), button_b=Button(x=25, y=23), prize=Prize(x=2855, y=1627)),
#         Task(button_a=Button(x=46, y=23), button_b=Button(x=49, y=93), prize=Prize(x=2124, y=2295)),
#         Task(button_a=Button(x=27, y=84), button_b=Button(x=53, y=11), prize=Prize(x=10279, y=17893)),
#         Task(button_a=Button(x=19, y=55), button_b=Button(x=42, y=23), prize=Prize(x=12761, y=2299)),
#         Task(button_a=Button(x=50, y=66), button_b=Button(x=75, y=30), prize=Prize(x=1550, y=1770)),
#         Task(button_a=Button(x=27, y=95), button_b=Button(x=85, y=17), prize=Prize(x=3986, y=3306)),
#         Task(button_a=Button(x=95, y=49), button_b=Button(x=19, y=85), prize=Prize(x=8056, y=7088)),
#         Task(button_a=Button(x=49, y=68), button_b=Button(x=88, y=34), prize=Prize(x=3014, y=2244)),
#         Task(button_a=Button(x=46, y=30), button_b=Button(x=17, y=41), prize=Prize(x=13436, y=18172)),
#         Task(button_a=Button(x=69, y=28), button_b=Button(x=23, y=60), prize=Prize(x=5566, y=3576)),
#         Task(button_a=Button(x=44, y=54), button_b=Button(x=12, y=82), prize=Prize(x=4236, y=11186)),
#         Task(button_a=Button(x=11, y=64), button_b=Button(x=79, y=24), prize=Prize(x=13813, y=11296)),
#         Task(button_a=Button(x=68, y=68), button_b=Button(x=13, y=93), prize=Prize(x=1895, y=3095)),
#         Task(button_a=Button(x=45, y=17), button_b=Button(x=44, y=77), prize=Prize(x=284, y=19673)),
#         Task(button_a=Button(x=68, y=14), button_b=Button(x=67, y=78), prize=Prize(x=8070, y=7440)),
#         Task(button_a=Button(x=73, y=11), button_b=Button(x=21, y=95), prize=Prize(x=1919, y=7085)),
#         Task(button_a=Button(x=26, y=72), button_b=Button(x=97, y=35), prize=Prize(x=2263, y=3697)),
#         Task(button_a=Button(x=33, y=13), button_b=Button(x=36, y=51), prize=Prize(x=17687, y=14407)),
#         Task(button_a=Button(x=62, y=35), button_b=Button(x=31, y=60), prize=Prize(x=15832, y=16295)),
#         Task(button_a=Button(x=62, y=29), button_b=Button(x=36, y=89), prize=Prize(x=8392, y=10059)),
#         Task(button_a=Button(x=55, y=28), button_b=Button(x=48, y=91), prize=Prize(x=6081, y=8554)),
#         Task(button_a=Button(x=13, y=34), button_b=Button(x=84, y=42), prize=Prize(x=2351, y=3128)),
#         Task(button_a=Button(x=14, y=31), button_b=Button(x=47, y=30), prize=Prize(x=13965, y=6961)),
#         Task(button_a=Button(x=88, y=74), button_b=Button(x=15, y=63), prize=Prize(x=7553, y=10735)),
#         Task(button_a=Button(x=70, y=20), button_b=Button(x=55, y=77), prize=Prize(x=11750, y=9118)),
#         Task(button_a=Button(x=43, y=61), button_b=Button(x=35, y=15), prize=Prize(x=5417, y=8049)),
#         Task(button_a=Button(x=46, y=25), button_b=Button(x=28, y=52), prize=Prize(x=4390, y=3379)),
#         Task(button_a=Button(x=25, y=57), button_b=Button(x=50, y=13), prize=Prize(x=2025, y=3102)),
#         Task(button_a=Button(x=62, y=13), button_b=Button(x=24, y=64), prize=Prize(x=1698, y=1023)),
#         Task(button_a=Button(x=16, y=71), button_b=Button(x=61, y=19), prize=Prize(x=5497, y=4908)),
#         Task(button_a=Button(x=23, y=97), button_b=Button(x=35, y=20), prize=Prize(x=3969, y=10486)),
#         Task(button_a=Button(x=96, y=24), button_b=Button(x=71, y=71), prize=Prize(x=5168, y=2144)),
#         Task(button_a=Button(x=44, y=73), button_b=Button(x=33, y=11), prize=Prize(x=15511, y=6412)),
#         Task(button_a=Button(x=42, y=23), button_b=Button(x=17, y=40), prize=Prize(x=1178, y=2018)),
#         Task(button_a=Button(x=44, y=95), button_b=Button(x=47, y=32), prize=Prize(x=7163, y=9560))
#     ]
# )
# 31552
